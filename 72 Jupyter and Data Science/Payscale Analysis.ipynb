# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
df = pd.read_csv('payscale_data.csv')
for column in ['Early Career Pay', 'Mid-Career Pay']:
    df[column] = [float(data[1:].replace(",", "")) for data in df[column]]
df['% High Meaning'] = [int(data[:-1]) if data != "-" else None for data in df['% High Meaning'] ]

df.head()
# Out:
#    Rank                                         Major Degree Type  \
# 0     1                         Petroleum Engineering   Bachelors
# 1     2  Operations Research & Industrial Engineering   Bachelors
# 2     3                            Interaction Design   Bachelors
# 3     4              Applied Economics and Management   Bachelors
# 4     5                              Building Science   Bachelors
#
#    Early Career Pay  Mid-Career Pay  % High Meaning
# 0         97,500.00      212,500.00           61.00
# 1         98,300.00      191,800.00           21.00
# 2         74,700.00      173,600.00           54.00
# 3         76,500.00      164,400.00           54.00
# 4         69,000.00      163,100.00           47.00

# %%
df = df.sort_values('% High Meaning', ascending=False)
df.head()
# Out:
#      Rank                      Major Degree Type  Early Career Pay  \
# 766   767              Music Therapy   Bachelors         48,500.00
# 107   108                   Medicine   Bachelors         88,700.00
# 567   568    Cardiopulmonary Science   Bachelors         56,500.00
# 305   304          Radiation Therapy   Bachelors         76,100.00
# 620   621  Applied Behavior Analysis   Bachelors         43,400.00
#
#      Mid-Career Pay  % High Meaning
# 766       63,500.00           95.00
# 107      124,700.00           94.00
# 567       83,200.00           92.00
# 305      102,600.00           91.00
# 620       80,000.00           88.00

# %%
pay_meaning = df['Mid-Career Pay'] * df['% High Meaning'] / 100000
df.insert(2, "Pay Meaning", pay_meaning)

# %%
df = df.sort_values("Pay Meaning")
df.head()
# Out:
#      Rank                           Major  Pay Meaning Degree Type  \
# 626   625          Commercial Photography        22.12   Bachelors
# 279   278                Japanese Studies        22.13   Bachelors
# 667   668     Fashion & Retail Management        22.50   Bachelors
# 536   535  Fashion Marketing & Management        23.11   Bachelors
# 584   582                      Web Design        23.87   Bachelors
#
#      Early Career Pay  Mid-Career Pay  % High Meaning
# 626         48,900.00       79,000.00           28.00
# 279         58,000.00      105,400.00           21.00
# 667         55,800.00       75,000.00           30.00
# 536         54,400.00       85,600.00           27.00
# 584         53,900.00       82,300.00           29.00

# %%
df = df.sort_values("Pay Meaning", ascending=False)
df.head()
# Out:
#      Rank                          Major  Pay Meaning Degree Type  \
# 0       1          Petroleum Engineering       129.62   Bachelors
# 12     13                       Pharmacy       121.66   Bachelors
# 107   108                       Medicine       117.22   Bachelors
# 8       9  Optical Science & Engineering       115.56   Bachelors
# 56     56    Physician Assistant Studies       113.30   Bachelors
#
#      Early Career Pay  Mid-Career Pay  % High Meaning
# 0           97,500.00      212,500.00           61.00
# 12          69,400.00      154,000.00           79.00
# 107         88,700.00      124,700.00           94.00
# 8           79,600.00      158,300.00           73.00
# 56         109,600.00      136,500.00           83.00

# %%
music = df.loc[df['Major'].str.contains('Music')]
music
# Out:
#      Rank                                 Major  Pay Meaning Degree Type  \
# 766   767                         Music Therapy        60.33   Bachelors
# 291   291        Music Production & Engineering        52.10   Bachelors
# 677   677  Instrumental Music Teacher Education        51.20   Bachelors
# 519   519                     Music Performance        48.50   Bachelors
# 588   588                                 Music        45.16   Bachelors
# 726   727               Music Teacher Education        40.48   Bachelors
# 668   669                     Music Composition        38.95   Bachelors
# 426   424                      Music Technology        35.30   Bachelors
# 758   759                       Musical Theatre        30.13   Bachelors
# 659   660                        Music Industry        29.03   Bachelors
# 515   516                            Musicology          NaN   Bachelors
#
#      Early Career Pay  Mid-Career Pay  % High Meaning
# ...
